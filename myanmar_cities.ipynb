# %%
import folium
import geopandas as gpd
import pyepsg

from folium import Element
from folium import plugins

# %%
towns = gpd.GeoDataFrame.from_file('./citiestownpopulation2013.geojson')

# %%
burma_map = folium.Map(location=[25, 100],
                   tiles='Mapbox Bright', zoom_start=5)
folium.GeoJson(towns.to_crs(epsg='4326').to_json(),
               name='geojson'
).add_to(burma_map)

# %%
burma_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
basin = gpd.read_file("./hydrobasinl3seasia1.geojson")

# %%
basin.plot()

# %%
geo_source = GeoJSONDataSource(geojson=basin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e4120dedbceb> in <module>()
# ----> 1 geo_source = GeoJSONDataSource(geojson=basin)
#
# /Users/papadopc/anaconda2/lib/python2.7/site-packages/bokeh/models/sources.pyc in __init__(self, *args, **kw)
#      86             else:
#      87                 raise ValueError("expected a dict or pandas.DataFrame, got %s" % raw_data)
# ---> 88         super(ColumnDataSource, self).__init__(**kw)
#      89         for name, data in raw_data.items():
#      90             self.add(data, name)
#
# /Users/papadopc/anaconda2/lib/python2.7/site-packages/bokeh/model.pyc in __init__(self, **kwargs)
#      83         self._id = kwargs.pop("id", make_id())
#      84         self._document = None
# ---> 85         super(Model, self).__init__(**kwargs)
#      86         default_theme.apply_to_model(self)
#      87
#
# /Users/papadopc/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.pyc in __init__(self, **properties)
#     701
#     702         for name, value in properties.items():
# --> 703             setattr(self, name, value)
#     704
#     705     def __setattr__(self, name, value):
#
# /Users/papadopc/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.pyc in __setattr__(self, name, value)
#     714
#     715         if name in props or name in deprecated:
# --> 716             super(HasProps, self).__setattr__(name, value)
#     717         else:
#     718             matches, text = difflib.get_close_matches(name.lower(), props), "similar"
#
# /Users/papadopc/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.pyc in __set__(self, obj, value)
#     453             raise RuntimeError("Cannot set a property value '%s' on a %s instance before HasProps.__init__" %
#     454                                (self.name, obj.__class__.__name__))
# --> 455         value = self.descriptor.prepare_value(obj.__class__, self.name, value)
#     456
#     457         old = self.__get__(obj)
#
# /Users/papadopc/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.pyc in prepare_value(self, cls, name, value)
#     270                     break
#     271             else:
# --> 272                 raise e
#     273         else:
#     274             value = self.transform(value)
#
# ValueError: expected a value of type basestring, got     cartodb_id                                           geometry  legend  \
# 0            1  (POLYGON ((109.0875 9.966666999999999, 109.083...       0
# 1            2  (POLYGON ((94.520833 17.579167, 94.520833 17.5...       0
# 2            3  (POLYGON ((96.533333 20.508333, 96.533333 20.5...      23
# 3            4  (POLYGON ((97.99166700000001 17.3875, 97.99583...      21
# 4            5  (POLYGON ((92.983333 32.729167, 92.9875 32.729...      22
# 5            6  (POLYGON ((98.925 19.770833, 98.920833 19.7708...      20
# 6            7  (POLYGON ((97.766667 28.770833, 97.770833 28.7...      24
# 7            8  (POLYGON ((101.279167 14.5, 101.283333 14.5, 1...      19
# 8            9  (POLYGON ((94.808333 33.591667, 94.82083299999...      18
# 9           10  (POLYGON ((106.414012 22.879167, 106.4125 22.8...      11
# 10          11  (POLYGON ((108.075 21.48278, 108.075 21.483333...      12
# 11          12  (POLYGON ((101.158333 25.1875, 101.170833 25.1...      16
# 12          13  (POLYGON ((107.170702 20.614548, 107.168487 20...      16
# 13          14  (POLYGON ((107.206776 20.615252, 107.208192 20...      16
# 14          16  (POLYGON ((107.132863 20.650405, 107.131468 20...      16
# 15          17  (POLYGON ((106.819167 20.667778, 106.817222 20...      16
# 16          21  (POLYGON ((107.02426 20.883333, 107.023539 20....      16
# 17          23  (POLYGON ((109.0875 9.966666999999999, 109.083...       0
# 18          15  (POLYGON ((107.158333 20.62011, 107.158333 20....      16
# 19          18  (POLYGON ((107.075053 20.700365, 107.073447 20...      16
# 20          19  (POLYGON ((106.916667 20.774394, 106.916667 20...      16
# 21          20  (POLYGON ((106.9 20.845833, 106.9 20.845833, 1...      16
# 22          22  (POLYGON ((106.995 20.936389, 106.995556 20.93...      16
# 23          24  (POLYGON ((94.520833 17.579167, 94.520833 17.5...       0
# 24          25  (POLYGON ((94.520833 17.579167, 94.520833 17.5...      25
# 25          26  (POLYGON ((109.0875 9.966666999999999, 109.083...      17
#
#     maj_area  maj_bas                         maj_name  sub_area  sub_bas  \
# 0     186187        0                             None         0        0
# 1      85714        0                             None         0        0
# 2      59680     5023                          Sittang      4972    23001
# 3     311477     5021               Peninsula Malaysia      9380    21001
# 4     265822     5022                          Salween     29221    22001
# 5     157686     5020                      Chao Phraya     26290    20001
# 6     402028     5024                        Irrawaddy     19942    24001
# 7      55013     5019           Gulf of Thailand Coast     21956    19006
# 8     803303     5018                           Mekong     19102    18001
# 9     412953     5011                        Xun Jiang      8663    11015
# 10     69644     5012            South China Sea Coast       619    12004
# 11    165007     5016                 Hong (Red River)      9507    16001
# 12    165007     5016                 Hong (Red River)     18095    16021
# 13    165007     5016                 Hong (Red River)     18095    16021
# 14    165007     5016                 Hong (Red River)     18095    16021
# 15    165007     5016                 Hong (Red River)     18095    16021
# 16    165007     5016                 Hong (Red River)     18095    16021
# 17    186187        0                             None         0        0
# 18    165007     5016                 Hong (Red River)     18095    16021
# 19    165007     5016                 Hong (Red River)     18095    16021
# 20    165007     5016                 Hong (Red River)     18095    16021
# 21    165007     5016                 Hong (Red River)     18095    16021
# 22    165007     5016                 Hong (Red River)     18095    16021
# 23     85714        0                             None         0        0
# 24     85714     5025  Bay of Bengal, North East Coast         0        0
# 25    186187     5017                  Viet Nam, Coast         0        0
#
#             sub_name  to_bas
# 0               None       0
# 1               None       0
# 2        Pyaunglaung   23002
# 3            Mottama    -999
# 4    Tanggula Shan 1   22003
# 5       Mae Nam Wang   20005
# 6           Nmai Hka   24008
# 7             Sa Keo    -999
# 8              Za Qu   18004
# 9        Zou Jiang 2   11019
# 10  GuangdongCoast 1    -999
# 11     Lishe Jiang 4   16005
# 12               Cau    -999
# 13               Cau    -999
# 14               Cau    -999
# 15               Cau    -999
# 16               Cau    -999
# 17              None       0
# 18               Cau    -999
# 19               Cau    -999
# 20               Cau    -999
# 21               Cau    -999
# 22               Cau    -999
# 23              None       0
# 24              None       0
# 25              None       0   of type GeoDataFrame

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="565b1bca-fc28-4a70-8a74-972e09334078">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.
# output_file("geojson.html")
# show(p)
